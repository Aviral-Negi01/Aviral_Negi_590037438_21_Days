# %% [markdown]
# # 21 days Python challenge
# ## Day 1 🔥

# %%
name = "Aviral"
print(name)
# Out:
# Aviral

# %%
age = 25
city = "Dehradun"
print(age, city)
# Out:
# 25 Dehradun

# %%
a = 10 # int 
b = 10.0 # float
c = "10" # string
d = True # bool
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
price = 499.99
print(type(price))
# Out:
# <class 'float'>

# %%
x = 10
print(x)

x = 20
print(x)
# Out:
# 10
# 20

# %%
name = "Python"
version = 3
print(name, version)
# Out:
# Python 3

# %%
student_name = "Rahul"
print(student_name)
# Out:
# Rahul

# %%
student_name #valid
2student # invalid
student2 #valid
student-name # invalid
_score # valid
# Out:
#   Cell In[8], line 2
#     2student # invalid
#     ^
# SyntaxError: invalid decimal literal

# %%
a = 5
b = 3
print(a + b) # 8
print(a*b)#15
# Out:
# 8
# 15

# %%
length = 10
width = 5
area_of_rectange = length*width
print(area_of_rectange)
# Out:
# 50

# %%
x = "10"
y = "20"
print(x + y) #1020
# Out:
# 1020

# %%
number = "25"
number = int(number)
print(number)
print(number + 5)
# Out:
# 25
# 30

# %%
price = 99.5
price = int(price)
print(price)
# Out:
# 99

# %%
a = 10 
b = 3

print(a/b) # 3.333
print(a//b)# 3
print(a%b) # 1
# Out:
# 3.3333333333333335
# 3
# 1

# %%
a , b, c = 10, 20, 30
print(a, b, c)
# Out:
# 10 20 30

# %%
x = 5
x = x + 10 # 15
x = x*2 # 30
print(x)
# Out:
# 30

# %%
item = "Laptop"
price = 500000
quantity = 2
total_price = price*quantity
print(total_price)
# Out:
# 1000000

# %%
age = "20"# age = 20
next_age = int(age) + 1
print(next_age)
# Out:
# 21

# %%
student_name = "Rahul"
age = 20
course = "Python Programming"

marks1 = 80
marks2 = 80
marks3 = 80
total_marks = marks1 + marks2 + marks3
average_marks= total_marks/3

print("Student:", student_name)
print("Age:", age)
print("Course:", course)
print("Total Marks:", total_marks)
print("Average Makrs", average_marks)
# Out:
# Student: Rahul
# Age: 20
# Course: Python Programming
# Total Marks: 240
# Average Makrs 80.0
