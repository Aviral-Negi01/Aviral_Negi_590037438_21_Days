# %% [markdown]
# # 21 days Python Challenge
# ## Day 3 😼

# %%
print(10 + 3, 10 - 3, 10 * 3)
# Out:
# 13 7 30

# %%
print(10 / 3) #division
print(10 // 3)# floor division
print(10 % 3)# modulus
# Out:
# 3.3333333333333335
# 3
# 1

# %%
print(2 ** 5) # exponential function

print( 2 ** 4 ** 2) #operates right to left
# Out:
# 32
# 65536

# %%
marks = [78, 91, 84, 67]
print(sum(marks), max(marks), min(marks))
# sum gives sum of all the values stored in the variable
# max gives the maximum value among all values
# min gives the minimum value among all values
# Out:
# 320 91 67

# %%
temperature_c = 30
print((temperature_c * 9 / 5) + 32)
# Out:
# 86.0

# %%
amount = 1250
gst = amount * 0.18
print(amount + gst)
# Out:
# 1475.0

# %%
number = 17
print(number % 2 == 0) # == is an relational operator
# Out:
# False

# %%
import math # math is a module used for mathematical functions such as roots and rounding
print(math.sqrt(144))
print(math.ceil(4.2), math.floor(4.8)) # ceil rounds up to nearest integer and floor down to nearest integer
# Out:
# 12.0
# 5 4

# %%
scores = [72, 88, 91]
average = sum(scores) / len(scores)#251/3 = 86.6666 
#  len() means length  
print(round(average, 1)) # round(average, 1) round off the average to 1 digit number
# Out:
# 83.7
