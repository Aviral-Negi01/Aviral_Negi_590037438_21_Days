# %% [markdown]
# # 21 Days Python Challenge
# ## Day 5 😺

# %%
student = {'name': 'Asha', 'age': 20}
print(student)
# Out:
# {'name': 'Asha', 'age': 20}

# %%
student = {'name': 'Asha'}
student['score'] = 92
print(student)
# Out:
# {'name': 'Asha', 'score': 92}

# %%
prices = {'pen': 10, 'book': 80}
print(prices['book'])
# Out:
# 80

# %%
profile = {'name': 'Ravi'}
print(profile.get('city', 'Unknown'))


profile = {'name': 'Ravi', 'city': 'Dehradun'}
print(profile.get('city', 'Unknown'))
# Out:
# Unknown
# Dehradun

# %%
scores = {'Math': 88, 'English': 76, 'Science': 91}
print(scores.keys())
print(scores.values())
# Out:
# dict_keys(['Math', 'English', 'Science'])
# dict_values([88, 76, 91])

# %%
cart = {'rice': 2, 'tea': 1}
cart['rice'] += 1 # += means rice = 1 + rice
print(cart)
# Out:
# {'rice': 3, 'tea': 1}

# %%
employee = {'name': 'Mira', 'department': 'Finance'}
for key, value in employee.items():
    print(key, value)
# Out:
# name Mira
# department Finance

# %%
word = 'banana'
counts = {}
for letter in word:
    counts[letter] = counts.get(letter, 0) + 1
print(counts)
# Out:
# {'b': 1, 'a': 3, 'n': 2}

# %%
word = 'banana'
counts = {}
for letter in word:
    counts[letter] = counts.get(letter, 0) + 1
print(counts)
# Out:
# {'b': 1, 'a': 3, 'n': 2}

# %%
products = [
    {'name': 'Pen', 'price': 10, 'quantity': 3},
    {'name': 'Book', 'price': 80, 'quantity': 2}
]
cart_total = sum(item['price'] * item['quantity'] for item in products)
print(cart_total)
# Out:
# 190

# %%
settings = {'dark_mode': False}
settings.update({'language': 'English', 'font_size': 14})
print(settings)
# Out:
# {'dark_mode': False, 'language': 'English', 'font_size': 14}
