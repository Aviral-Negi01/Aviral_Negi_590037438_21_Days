# %% [markdown]
# # 21 Days Python Challenge
# ## Day 11 🥷🏻

# %%
message = 'outside'
def show_message():
    print(message)
show_message()
# Out:
# outside

# %%
def make_message():
    message = 'inside'
    return message
print(make_message())
# Out:
# inside

# %%
def divide(first, second):
    return first / second, first % second
quotient, remainder = divide(17, 5)
print(quotient, remainder)
# Out:
# 3.4 2

# %%
def min_max(values):
    return min(values), max(values)
print(min_max([4, 9, 1]))
# Out:
# (1, 9)

# %%
def operations(a, b):
    return {'sum': a + b, 'product': a * b}
print(operations(3, 4))
# Out:
# {'sum': 7, 'product': 12}

# %%
tax_rate = 0.18
def price_with_tax(price):
    return price * (1 + tax_rate)
print(price_with_tax(500))
# Out:
# 590.0

# %%
def counter():
    count = 0
    count += 1
    return count
print(counter(), counter())
# Out:
# 1 1

# %%
def format_person(person):
    return f"{person['name']} is {person['age']} years old"
print(format_person({'name': 'Mira', 'age': 22}))
# Out:
# Mira is 22 years old

# %%
def calculate_bill(items):
    subtotal = sum(item['price'] for item in items)
    return subtotal, subtotal * 1.18
print(calculate_bill([{'price': 100}, {'price': 50}]))
# Out:
# (150, 177.0)

# %%
def describe(value):
    if value is None:
        return 'No value'
    return f'Value: {value}'
print(describe(None), describe(10))
# Out:
# No value Value: 10
